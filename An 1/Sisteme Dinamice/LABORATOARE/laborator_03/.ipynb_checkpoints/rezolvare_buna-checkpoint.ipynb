# %% [raw]
# #LABORATOR 3
# #Exercitiul 1

# %% [raw]
# a)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1 = diff(x, t) == x + 4 * y
eq2 = diff(y, t) == x + y
syst=[eq1, eq2]

sol = desolve_system(syst, [x,y])


C1, C2=var('C1,C2')
sol_const = desolve_system(syst, [x,y], ics=[0, C1, C2])
show(sol_const)
# Out:
# [x(t) == 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t),
#  y(t) == 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)]

# %% [raw]
# b)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1 = diff(x, t) == 2*x - y
eq2 = diff(y, t) == x + 2*y
syst=[eq1, eq2]

sol = desolve_system(syst, [x,y])

C1, C2=var('C1, C2')
sol_const = desolve_system(syst, [x,y], ics=[0, C2, C1])
show(sol_const)
# Out:
# [x(t) == (C2*cos(t) - C1*sin(t))*e^(2*t),
#  y(t) == (C1*cos(t) + C2*sin(t))*e^(2*t)]

# %% [raw]
# c)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
eq1 = diff(x, t) == x - y + z
eq2 = diff(y, t) == x + y - z
eq3 = diff(z, t) == -y + 2*z
syst=[eq1, eq2, eq3]

sol = desolve_system(syst, [x,y,z])

C1, C2, C3=var('C1, C2, C3')
sol_const = desolve_system(syst, [x,y,z], ics=[0, C2, C1, C3])
show(sol_const)
# Out:
# [x(t) == C2*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + 2*C2 - 2*C3)*e^t,
#  y(t) == C2*t*e^t - C3*t*e^t + C1*e^t,
#  z(t) == C2*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t]

# %% [raw]
# d)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1 = diff(x, t) == 5*x + 3*y + 1
eq2 = diff(y, t) == -6*x - 4*y + exp(-t)
syst=[eq1, eq2]

sol = desolve_system(syst, [x,y])

C1,C2=var('C1,C2')
sol_const = desolve_system(syst, [x,y], ics=[0, C2, C1])
show(sol_const)
# Out:
# [x(t) == 1/3*(3*C1 + 6*C2 + 4)*e^(2*t) - 1/3*(3*C1 + 3*C2 - 2)*e^(-t) - t*e^(-t) - 2,
#  y(t) == -1/3*(3*C1 + 6*C2 + 4)*e^(2*t) + 1/3*(6*C1 + 6*C2 - 5)*e^(-t) + 2*t*e^(-t) + 3]

# %% [raw]
# e)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1 = diff(x, t) == x + 3*y + cos(t)
eq2 = diff(y, t) == x - y + 2*t
syst=[eq1, eq2]

sol = desolve_system(syst, [x,y])

C1,C2=var('C1,C2')
sol_const = desolve_system(syst, [x,y], ics=[0, C2, C1])
show(sol_const)
# Out:
# [x(t) == 3/40*(10*C1 + 10*C2 + 9)*e^(2*t) - 1/40*(30*C1 - 10*C2 + 19)*e^(-2*t) - 3/2*t - 1/5*cos(t) + 1/5*sin(t),
#  y(t) == 1/40*(10*C1 + 10*C2 + 9)*e^(2*t) + 1/40*(30*C1 - 10*C2 + 19)*e^(-2*t) + 1/2*t - 1/5*cos(t) - 1/2]

# %% [raw]
# f)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
eq1 = diff(x, t) == x - y + z
eq2 = diff(y, t) == x + y - z
eq3 = diff(z, t) == -y + 2*z
syst=[eq1, eq2, eq3]

sol = desolve_system(syst, [x,y,z])

C1, C2, C3=var('C1, C2, C3')
sol_const = desolve_system(syst, [x,y,z], ics=[0, C2, C1, C3])
show(sol_const)
# Out:
# [x(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) - 2*z(0) + 2)*e^(2*t) + 2*(x(0) - z(0) + 1)*e^t,
#  y(t) == t*e^t*x(0) - t*e^t*z(0) + 2*e^t,
#  z(t) == t*e^t*x(0) - t*e^t*z(0) - (x(0) - 2*z(0) + 2)*e^(2*t) + (x(0) - z(0) + 2)*e^t]

# %% [raw]
# Exercitiul 2

# %% [raw]
# a)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1 = diff(x,t) == x+4*y
eq2 = diff(y,t) == x + y
syst=[eq1, eq2]
sol = desolve_system(syst, [x,y], ics=[0, 1, 2])
show(sol)
# Out:
# 5/2*e^(3*t) - 3/2*e^(-t)

# %%
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot(sol_x(t), t, -1, 1, color='red')
g2=plot(sol_y(t), t, -1, 1, color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [raw]
# b)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1 = diff(x,t) == x-y+t-1
eq2 = diff(y,t) == -2*x+4*y+cos(t)
syst=[eq1, eq2]
sol = desolve_system(syst, [x,y], ics=[0, 0, 1])
show(sol)
# Out:
# [x(t) == -1/13*(10*sqrt(17)*sinh(1/2*sqrt(17)*t) - 33*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2,
#  y(t) == -1/26*(3*sqrt(17)*sinh(1/2*sqrt(17)*t) - 71*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2]

# %%
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot(sol_x(t), t, -0.5, 0.5,ymax = 10, ymin = -10, color='red')
g2=plot(sol_y(t), t, -0.5, 0.5,ymax = 10, ymin = -10, color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [raw]
# c)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1 = diff(x,t) == x+2*y+exp(-t)
eq2 = diff(y,t) == -2*x+y+1
syst=[eq1, eq2]
sol = desolve_system(syst, [x,y], ics=[0, 0, 1])
show(sol)
# Out:
# [x(t) == -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5,
#  y(t) == 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5]

# %%
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
g1=plot(sol_x(t), t, -5, 4,ymax = 10, ymin = -10, color='red', detect_poles=true)
g2=plot(sol_y(t), t, -5, 4,ymax = 10, ymin = -10, color='blue', detect_poles=true)
show(g1+g2)
# Out:
# Graphics object consisting of 4 graphics primitives

# %% [raw]
# d)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
eq1 = diff(x,t) == -x+3*y+3*z+27*t^2
eq2 = diff(y,t) == 2*x-2*y-5*z+3*t
eq3 = diff(z,t) == -2*x+3*y+6*z+3
syst=[eq1, eq2, eq3]
sol = desolve_system(syst, [x,y,z], ics=[0, 50, -30, 26])
show(sol)
# Out:
# [x(t) == 27*t^2 - 63*t + 2*e^(-t) + 3*e^t + 45,
#  y(t) == -18*t^2 + 24*t + e^(3*t) - e^(-t) + 2*e^t - 32,
#  z(t) == 18*t^2 - 27*t - e^(3*t) + e^(-t) + 26]

# %%
sol_x(t)=sol[0].rhs()
sol_y(t)=sol[1].rhs()
sol_z(t)=sol[2].rhs()
g1=plot(sol_x(t), t, -15, 15,ymax = 50, ymin = -50, color='red', detect_poles=true)
g2=plot(sol_y(t), t, -15, 15,ymax = 50, ymin = -50, color='blue', detect_poles=true)
g3=plot(sol_z(t), t, -15, 15,ymax = 50, ymin = -50, color='green', detect_poles=true)
show(g1+g2+g3)
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [raw]
# Exercitiul 3

# %% [raw]
# a)

# %%
t,C1,C2=var('t,C1,C2')
x=function('x')(t)
y=function('y')(t)
eq1 = diff(x,t) == x+y
eq2 = diff(y,t) == -2*x+4*y
syst=[eq1, eq2]
sol(C1,C2) = desolve_system(syst, [x,y], ics=[0, C1,C2])
show(sol(C1,C2))
# Out:
# (x(t) == -(C1 - C2)*e^(3*t) + (2*C1 - C2)*e^(2*t), y(t) == -2*(C1 - C2)*e^(3*t) + (2*C1 - C2)*e^(2*t))

# %%
show(sol(3,0))
show(sol(0,3))
show(sol(-3,0))
show(sol(0,-3))
# Out:
# (x(t) == -3*e^(3*t) + 6*e^(2*t), y(t) == -6*e^(3*t) + 6*e^(2*t))
# (x(t) == 3*e^(3*t) - 3*e^(2*t), y(t) == 6*e^(3*t) - 3*e^(2*t))
# (x(t) == 3*e^(3*t) - 6*e^(2*t), y(t) == 6*e^(3*t) - 6*e^(2*t))
# (x(t) == -3*e^(3*t) + 3*e^(2*t), y(t) == -6*e^(3*t) + 3*e^(2*t))

# %% [raw]
# b)

# %%
sol_x1=sol(3,0)[0].rhs()
limit(sol_x1, t=infinity)
# Out:
# -Infinity

# %%
sol_y1=sol(3,0)[1].rhs()
limit(sol_y1, t=infinity)
# Out:
# -Infinity

# %%
sol_x2=sol(0,3)[0].rhs()
limit(sol_x2, t=infinity)
# Out:
# +Infinity

# %%
sol_y2=sol(0,3)[1].rhs()
limit(sol_y2, t=infinity)
# Out:
# +Infinity

# %%
sol_x3=sol(-3,0)[0].rhs()
limit(sol_x3, t=infinity)
# Out:
# +Infinity

# %%
sol_y3=sol(-3,0)[1].rhs()
limit(sol_y3, t=infinity)
# Out:
# +Infinity

# %%
sol_x4=sol(0,-3)[0].rhs()
limit(sol_x4, t=infinity)
# Out:
# -Infinity

# %%
sol_y4=sol(0,-3)[1].rhs()
limit(sol_y4, t=infinity)
# Out:
# -Infinity

# %% [raw]
# c)

# %%
F1(u,v)=u+v
F2(u,v)=-2*u+4*v
g1=plot_vector_field([F1(u,v), F2(u,v)], [u,-10,10], [v,-10,10], color='red', aspect_ratio=1)
g2=parametric_plot((sol_x1(t), sol_y1(t)), (t,-10,10), color='blue')
g3=parametric_plot((sol_x2(t), sol_y2(t)), (t,-10,10), color='blue')
g4=parametric_plot((sol_x3(t), sol_y3(t)), (t,-10,10), color='blue')
g5=parametric_plot((sol_x4(t), sol_y4(t)), (t,-10,10), color='blue')
g=g1+g2+g3+g4+g5
g.show(xmin=-10, xmax=10, ymin=-10, ymax=10)
# Out:
# Graphics object consisting of 5 graphics primitives

# %% [raw]
# Exercitiul 4

# %% [raw]
# a)

# %%
t=var('t')
x=function('x')(t)
y=function('y')(t)
eq1 = diff(x,t) == y
eq2 = diff(y,t) == -x-2*y
syst=[eq1, eq2]
sol(C1,C2) = desolve_system(syst, [x,y], ics=[0, C1,C2])
show(sol(C1,C2))
# Out:
# (x(t) == C1*t*e^(-t) + C2*t*e^(-t) + C1*e^(-t), y(t) == -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t))

# %% [raw]
# b)

# %%
sol_x(t)=sol(C1,C2)[0].rhs()
limit(sol_x(t), t=infinity)
# Out:
# 0

# %%
sol_y(t)=sol(C1,C2)[1].rhs()
limit(sol_y(t), t=infinity)
# Out:
# 0

# %% [raw]
# c)

# %%
F1(u,v)=v
F2(u,v)=-u-2*v
plot_vector_field([F1(u,v), F2(u,v)], [u, -10,10],[v,-10,10], color='red', aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# Exercitiul 5

# %% [raw]
# a)

# %%
F1(u,v)=2*u+v
F2(u,v)=u+2*v
plot_vector_field([F1(u,v), F2(u,v)], [u,-10,10], [v,-10,10], color='red', aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# limitele nu sunt 0

# %% [raw]
# b)

# %%
F1(u,v)=-u-v
F2(u,v)=u-v
plot_vector_field([F1(u,v), F2(u,v)], [u,-10,10],[v,-10,10], color='red', aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# limitele sunt 0

# %% [raw]
# c)

# %%
F1(u,v)=v
F2(u,v)=-u
plot_vector_field([F1(u,v), F2(u,v)], [u,-10,10], [v,-10,10], color='red', aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# limitele nu sunt 0

# %% [raw]
# d)

# %%
F1(u,v)=-2*u
F2(u,v)=-4*u-2*v
plot_vector_field([F1(u,v), F2(u,v)], [u, -10,10], [v,-10,10], color='red', aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# limita nu sunt 0

# %% [raw]
# e)

# %%
F1(u,v)=u-4*v
F2(u,v)=5*u-3*v
plot_vector_field([F1(u,v), F2(u,v)], [u,-10,10], [v,-10,10], color='red', aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# limitele nu sunt 0

# %% [raw]
# f)

# %%
F1(u,v)=3*u-v
F2(u,v)=v
plot_vector_field([F1(u,v), F2(u,v)], [u,-10,10], [v,-10,10], color='red', aspect_ratio=1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# limitele nu sunt 0
