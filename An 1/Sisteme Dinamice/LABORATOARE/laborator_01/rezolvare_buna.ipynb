# %% [raw]
# Exercitiul 1

# %% [raw]
# a)

# %%
12+4-5
# Out:
# 11

# %% [raw]
# b)

# %%
2^10
# Out:
# 1024

# %% [raw]
# c)

# %%
sin(pi/2)
# Out:
# 1

# %%
sin(0.1)
# Out:
# 0.0998334166468282

# %% [raw]
# d)

# %%
14+2*(5-3)
# Out:
# 18

# %% [raw]
# Exercitiul 2

# %% [raw]
# a)

# %%
x = var('x')
p1 = x^4 - 3/2*(x^3) - x + 3/2 == 0
solve(p1, x)
# Out:
# [x == 1, x == (3/2), x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %% [raw]
# b)

# %%
x = var('x')
p2 = sqrt(x^2+2*x) == 3
solve(p2, x)
# Out:
# [x == -sqrt(10) - 1, x == sqrt(10) - 1]

# %% [raw]
# c)

# %%
x, y = var('x, y')
syst = solve([2*x+y == 3, x+3*y == -1], x, y)
syst
# Out:
# [[x == 2, y == -1]]

# %% [raw]
# d)

# %%
x, y = var('x, y')
syst = solve([2*x + x*y + 2*y == 59, 3*x - 2*x*y + 3*y == -34], x, y)
syst
# Out:
# [[x == 7, y == 5], [x == 5, y == 7]]

# %% [raw]
# Exercitiul 3

# %% [raw]
# a)

# %%
lim(sin(x)/x, x = 0)
# Out:
# 1

# %% [raw]
# b)

# %%
 lim((x^3 + 3*(x^2) - 5)/(2*(x^3) - 7*x), x = infinity)
# Out:
# 1/2

# %% [raw]
# c)

# %%
lim((cos(x) + 1)/(x - pi), x = pi)
# Out:
# 0

# %% [raw]
# Exercitiul 4

# %% [raw]
# a)

# %%
f(x) = 3*(x^3) + 2*(x^2) - 5
diff(f(x), x)
# Out:
# 9*x^2 + 4*x

# %% [raw]
# b)

# %%
f(x) = sqrt(1 + x^4)
diff(f(x), x)
# Out:
# 2*x^3/sqrt(x^4 + 1)

# %% [raw]
# c)

# %%
f(x) = exp(x) * sin(x) * cos(x)
diff(f(x), x)
# Out:
# cos(x)^2*e^x + cos(x)*e^x*sin(x) - e^x*sin(x)^2

# %% [raw]
# Exercitiul 5

# %% [raw]
# a)

# %%
f(x) = 3*(x^3) + 2*(x^2) - 5
integrate(f(x), x, 0, 1)
# Out:
# -43/12

# %% [raw]
# b)

# %%
x = var('x')
integrate(1/(x^2), x, 1, infinity)
# Out:
# 1

# %% [raw]
# c)

# %%
x = var('x')
integrate(exp(-(x^2)), x, -infinity, infinity)
# Out:
# sqrt(pi)

# %% [raw]
# Exercitiul 6

# %% [raw]
# a)

# %%
f(x) = exp(-x) - 1
plot(f(x), -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# b)

# %%
f(r, x) = (200 * exp(r * x)) / (2 * (exp(r*x) - 1) + 100)
plot([f(0.5, x), f(-0.5, x)], 0, 50, color = ['red', 'blue'])
# Out:
# Graphics object consisting of 2 graphics primitives

# %% [raw]
# c)

# %%
f(x) = x * sin (1 / x)
plot(f(x), -3, 3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# Exercitiul 7

# %% [raw]
# a)

# %%
t = var('t')
x(t) = (1 - cos(t)) * cos(t)
y(t) = (1 - cos(t)) * sin(t)
parametric_plot((x(t), y(t)), (t, 0, 2 * pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# b)

# %%
t = var('t')
x(t) = sin(3*t) * cos(t)
y(t) = sin(3*t) * sin(t)

# %%
parametric_plot((x(t), y(t)), (t, 0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# c)

# %%
t = var('t')
x(t) = t - sin(t)
y(t) = 1- cos(t)
parametric_plot((x(t), y(t)), (t, 0, 6*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# d)

# %%
t = var('t')
x(t) = cos(t) + cos(7*t)/2 + sin(17*t)/3
y(t) = sin(t) + sin(7*t)/2 + cos(17*t)/3
parametric_plot((x(t), y(t)), (t, 0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# Exercitiul 8

# %% [raw]
# a)

# %%
t,s = var('t,s')
f(t,s) = 1 - (s * cos(4*t) * cos(t))/(sqrt(1 - s^2 * (cos(4 *t))^2 * (sin(t))^2))
x(t, s) = f(t - pi/2, s)
y(t, s) = f(t, s)
parametric_plot((x(t, 0.5), y(t, 0.5)), (t, 0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# b)

# %%
t,s = var('t,s')
f(t,s) = 1 - (s * cos(4*t) * cos(t))/(sqrt(1 - s^2 * (cos(4 *t))^2 * (sin(t))^2))
x(t, s) = f(t - pi/2, s)
y(t, s) = f(t, s)
g = parametric_plot((x(t, 0.5), y(t, 0.5)), (t, 0, 2*pi))
for k in [1..10]:
    g1 = parametric_plot((x(t, k/10), y(t, k/10)), (t, 0, 2*pi))
    g=g+g1
show(g1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# Exercitiul 9

# %% [raw]
# a)

# %%
f(x, y) = x^2 + y^2 - 2 * x - 4*y + 4
implicit_plot(f(x, y) == 0, (x, 0, 3), (y, 0, 3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# b)

# %%
f(x, y) = x^2 - 2*x*y - y^2
implicit_plot(f(x, y) == 1, (x, -10, 10), (y, -10, 10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# c)

# %%
f(x, y) = 6 * x^2 - 4*x*y + 9*y^2 - 4*x - 32*y - 6
implicit_plot(f(x, y) == 0, (x, -2, 5), (y, -2, 5))
# Out:
# Graphics object consisting of 1 graphics primitive
