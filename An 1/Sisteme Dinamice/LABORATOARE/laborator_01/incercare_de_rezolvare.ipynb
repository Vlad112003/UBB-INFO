# %%
12+4-5
# Out:
# 11

# %%
2**10
# Out:
# 1024

# %%
sin(pi/2)
# Out:
# 1

# %%
sin(0.1)
# Out:
# 0.0998334166468282

# %%
14+2*(5-3)
# Out:
# 18

# %%
x=var('x')
eq=x**4-3/2*x**3-x+3/2==0
solve(eq,x)
# Out:
# [x == 1, x == (3/2), x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %%
x=var('x')
eq=sqrt(x**2+2*x)==3
solve(eq,x)
# Out:
# [x == -sqrt(10) - 1, x == sqrt(10) - 1]

# %%
x,y=var('x,y')
syst=[2*x+y==3,x+3*y==-1]
solve(syst,x,y)
# Out:
# [[x == 2, y == -1]]

# %%
x,y=var('x,y')
syst=[2*x+x*y+2*y==59,3*x-2*x*y+3*y==-34]
solve(syst,x,y)
# Out:
# [[x == 7, y == 5], [x == 5, y == 7]]

# %%
x=var('x')
limit(sin(x)/x,x=0)
# Out:
# 1

# %%
x=var('x')
limit((x**3+3*x-5)/(2*x**3-7*x),x=infinity)
# Out:
# 1/2

# %%
x=var('x')
limit((cos(x)+1)/(x-pi),x=pi)
# Out:
# 0

# %%
x=var('x')
diff(3*x**3+2*x**2-5,x)
# Out:
# 9*x^2 + 4*x

# %%
x=var('x')
diff(sqrt(1+x**4),x)
# Out:
# 2*x^3/sqrt(x^4 + 1)

# %%
x=var('x')
diff(e**x*sin(x)*cos(x),x)
# Out:
# cos(x)^2*e^x + cos(x)*e^x*sin(x) - e^x*sin(x)^2

# %%
integrate(3*x**3+2*x**2-5,x,0,1)
# Out:
# -43/12

# %%
integrate(1/x**2,x,1,infinity)
# Out:
# 1

# %%
integrate(e**-x**2,x,-infinity,infinity)
# Out:
# sqrt(pi)

# %%
f(x)=e**-x-1
plot(f(x),-2,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(x,r)=(200*e**(r*x))/(2*(e**(r*x)-1)+100)
plot([f(x,0.5),f(x,-0.5)],0,50)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f(x)=x*sin(1/x)
plot(f(x),-3,3,detect_poles=True)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x (t) = sin(3*t)*cos(t)
y (t) = sin(3*t)*sin(t)
parametric_plot((x(t), y(t)), (t, 0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x (t) = t-sin(t)
y (t) = 1-cos(t)
parametric_plot((x(t), y(t)), (t, 0, 6*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x (t) = cos(t)+cos(7*t)/2+sin(17*t)/3
y (t) = sin(t)+sin(7*t)/2+cos(17*t)/3
parametric_plot((x(t), y(t)), (t, 0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(t,s)=1-((s*cos(4*t)*cos(t))/sqrt(1- s**2* (cos(4*t))**2* (sin(t))**2 ))
x(t,s) = f(t-pi/2,s)
y(t,s) = f(t,s)
parametric_plot((x(t,0.5), y(t,0.5)), (t, 0, 2*pi))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f(t,s)=1-((s*cos(4*t)*cos(t))/sqrt(1- s**2* (cos(4*t))**2* (sin(t))**2 ))
x(t,s) = f(t-pi/2,s)
y(t,s) = f(t,s)
g1=parametric_plot((x(t,0.1), y(t,0.1)), (t, 0, 2*pi))
g2=parametric_plot((x(t,0.2), y(t,0.2)), (t, 0, 2*pi))
g3=parametric_plot((x(t,0.3), y(t,0.3)), (t, 0, 2*pi))
g4=parametric_plot((x(t,0.4), y(t,0.4)), (t, 0, 2*pi))
g5=parametric_plot((x(t,0.5), y(t,0.5)), (t, 0, 2*pi))
g6=parametric_plot((x(t,0.6), y(t,0.6)), (t, 0, 2*pi))
g7=parametric_plot((x(t,0.7), y(t,0.7)), (t, 0, 2*pi))
g8=parametric_plot((x(t,0.8), y(t,0.8)), (t, 0, 2*pi))
g9=parametric_plot((x(t,0.9), y(t,0.9)), (t, 0, 2*pi))
g10=parametric_plot((x(t,1), y(t,1)), (t, 0, 2*pi))
show(g1+g2+g3+g4+g5+g6+g7+g8+g9+g10)
# Out:
# Graphics object consisting of 10 graphics primitives

# %%
x,y=var('x,y')
f(x,y)=x**2+y**2-2*x-4*y+4
implicit_plot(f(x,y)==0,(x,-1,3),(y,0.5,3))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y=var('x,y')
f(x,y)=x**2-2*x*y-y**2
implicit_plot(f(x,y)==1,(x,-10,10),(y,-10,10))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y=var('x,y')
f(x,y)=6*x**2-4*x*y+9*y**2-4*x-32*y-6
implicit_plot(f(x,y)==0,(x,-4,6),(y,-1,5))
# Out:
# Graphics object consisting of 1 graphics primitive
