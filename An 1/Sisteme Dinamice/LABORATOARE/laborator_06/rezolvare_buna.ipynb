# %% [markdown]
# # Laborator 6

# %%
reset()
t = var('t')
x = function('x')(t)

s = var('s')
f = function('f')(s)

f(s) = s*(1 - s^2)

eqp = solve(f(s) == 0, s)
show(eqp)
# Out:
# [s == -1, s == 1, s == 0]

# %%
x1 = eqp[0].rhs()
x2 = eqp[1].rhs()
x3 = eqp[2].rhs()

show("Pt x1 = -1\n")
show(diff(f, s)(x1))
show("=> Punct de echilibru asimptotic stabil\n")

show("Pt x1 = 1\n")
show(diff(f, s)(x2))
show("=> Punct de echilibru asimptotic stabil\n")

show("Pt x1 = 0\n")
show(diff(f, s)(x3))
show("=> Punct de echilibru instabil\n")
# Out:
# 'Pt x1 = -1\n'
# -2
# '=> Punct de echilibru asimptotic stabil\n'
# 'Pt x1 = 1\n'
# -2
# '=> Punct de echilibru asimptotic stabil\n'
# 'Pt x1 = 0\n'
# 1
# '=> Punct de echilibru instabil\n'

# %%
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3),headaxislength=3, headlength=4,color='red')
sf
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
eq = diff(x, t) == f(x)
eq
# Out:
# diff(x(t), t) == -(x(t)^2 - 1)*x(t)

# %%
desolve_rk4(eq, x, [0,0.5], step = 0.5, end_points = [-5, 5], output = 'list')
desolve_rk4(eq, x, [0,0.5], step = 0.5, end_points = [-5, 5], output = 'plot')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Sisteme planare

# %%
reset()
A = matrix([[1, 1], [1, -1]])
show(A)
# Out:
# [ 1  1]
# [ 1 -1]

# %%
A.eigenvalues()
# Out:
# [-1.414213562373095?, 1.414213562373095?]

# %%
cp(x) = A.charpoly()
show(cp)
# Out:
# x |--> x^2 - 2

# %%
solve(cp == 0, x)
# Out:
# [x == -sqrt(2), x == sqrt(2)]

# %%
x, y, t = var('x, y, t')
f1(x, y) = x + y
f2(x, y) = x - y
desolve_system_rk4([f1(x, y), f2(x, y)], [x, y], ics = [0, 1, -1] ,ivar = t, end_points = [-1, 1], step = 0.1)
# Out:
# [[-1.0, 2.178175582521938, -4.914760225614616],
#  [-0.9, 1.925422767612532, -4.252331374129021],
#  [-0.8, 1.711242398200907, -3.675090485140899],
#  [-0.7000000000000001, 1.531343747591895, -3.17147355560485],
#  [-0.6000000000000001, 1.382122862773177, -2.73139150871942],
#  [-0.5, 1.260590365556255, -2.346028077070541],
#  [-0.4, 1.164311565637939, -2.007663184267604],
#  [-0.3, 1.091357685852782, -1.709518286834819],
#  [-0.2, 1.0402672225, -1.445620578055556],
#  [-0.1, 1.010016666666667, -1.210683333333333],
#  [0, 1, -1],
#  [0.1, 1.010016666666667, -0.80935],
#  [0.2, 1.0402672225, -0.6349138669444444],
#  [0.3, 1.091357685852782, -0.4731970848707454],
#  [0.4, 1.164311565637939, -0.3209599470082735],
#  [0.5, 1.260590365556255, -0.1751526540419697],
#  [0.6000000000000001, 1.382122862773177, -0.0328542168269349],
#  [0.7000000000000001, 1.531343747591894, 0.1087860604210598],
#  [0.8, 1.711242398200906, 0.2526056887390845],
#  [0.9, 1.925422767612531, 0.4014858389039571],
# ...

# %%
P=desolve_system_rk4([f1(x,y),f2(x,y)], [x,y], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)
XY=[ [j, k] for i,j,k in P]
XY
list_plot(XY, plotjoined = true, color = 'blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [markdown]
# # Problema 1
#
# # a)

# %%
t = var('t')
x = function('x')(t)

eq = diff(x, t) == x^2 - 2*x

s = var('s')
f(s) = s^2 - 2*s

sol = solve(f(s) == 0, s)
show(sol)
# Out:
# [s == 0, s == 2]

# %%
sf = plot_slope_field(f(s), (t, -5, 5), (s, -3, 3), headaxislength = 3, headlength = 4, color ='red')
sf
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
desolve_rk4(eq, x, [0, 0.5], step = 0.5, end_points = [-5, 5], output='plot')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
desolve_rk4(eq, x, [0, 0.5], step = 0.5, end_points = [-5, 5], output='slope_field')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
x1 = sol[0].rhs()
x2 = sol[1].rhs()
v1 = diff(f, s)(x1) # -2 => punct de echilibru asimptotic stabil
show(v1)

v2 = diff(f, s)(x2) # 2 => punct de echilibru instabil
show(v2)
# Out:
# -2
# 2

# %%
sf=plot_slope_field(f(s),(t,-5,5),(s,-3,3),headaxislength=3, headlength=4,color='red')
g1 = desolve_rk4(eq, x, [0, -0.5], step=0.01, end_points = [-5, 5], output = 'plot')
g2 = desolve_rk4(eq, x, [0, 0], step=0.01, end_points = [-5, 5], output = 'plot')
g4 = desolve_rk4(eq, x, [0, 1], step=0.01, end_points = [-5, 5], output = 'plot')
g6 = desolve_rk4(eq, x, [0, 2], step=0.01, end_points = [-5, 5], output = 'plot')
g7 = desolve_rk4(eq, x, [0, 2.5], step=0.01, end_points = [-5, 5], output = 'plot')

g = sf + g1 + g2 + g4 + g6 + g7
g.show(ymin = -3, ymax = 3)
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [markdown]
# # b)

# %%
reset()
t = var('t')
x = function('x')(t)

eq = diff(x, t) == x* (x - 1)* (x - 2)

s = var('s')
f = function('f')(s)
f(s) = s*(s-1)*(s-2)

show(f)

sol = solve(f(s) == 0, s)
show(sol)
# Out:
# s |--> (s - 1)*(s - 2)*s
# [s == 0, s == 1, s == 2]

# %%
x1 = sol[0].rhs()
x2 = sol[1].rhs()
x3 = sol[2].rhs()
show(diff(f, s)(x1)) # 2 => punct de echilibru instabil
show(diff(f, s)(x2)) # -1 < 0 => punct de echilibru asimptotic stabil
show(diff(f, s)(x3)) # 2 > 0 => punct de echilibru instabil
# Out:
# 2
# -1
# 2

# %%
sf=plot_slope_field(f(s), (t, -5, 5), (s, -3, 3), headaxislength=3, headlength=4,color='red')
g1 = desolve_rk4(eq, x, [0, -0.5], step=0.01, end_points = [-5, 5], output = 'plot')
g2 = desolve_rk4(eq, x, [0, 0], step=0.01, end_points = [-5, 5], output = 'plot')
g3 = desolve_rk4(eq, x, [0, 0.5], step=0.01, end_points = [-5, 5], output = 'plot')
g4 = desolve_rk4(eq, x, [0, 1], step=0.01, end_points = [-5, 5], output = 'plot')
g5 = desolve_rk4(eq, x, [0, 1.5], step=0.01, end_points = [-5, 5], output = 'plot')
g6 = desolve_rk4(eq, x, [0, 2], step=0.01, end_points = [-5, 5], output = 'plot')
g7 = desolve_rk4(eq, x, [0, 2.5], step=0.01, end_points = [-5, 5], output = 'plot')
g = sf + g1 + g2 + g3 + g4 + g5 + g6 + g7
g.show(ymin = -3, ymax = 3)
# Out:
# Graphics object consisting of 8 graphics primitives

# %% [markdown]
# # c)

# %%
reset()
t = var('t')
x = function('x')(t)

eq = diff(x, t) == sin(x)
show(eq)

s = var('s')
f = function('f')(s)
f(s) = sin(s)
show(f)

sol = solve(f(s) == 0, s, to_poly_solve = 'force')
show(sol)
# Out:
# diff(x(t), t) == sin(x(t))
# s |--> sin(s)
# [s == pi*z20]

# %%
x1 = sol[0].rhs()
show(x1)
show(diff(f, s)(x1))
#Conform teoremei stabilitatii in prima aproximatie
#Pentru solutiile in care pi*z0 este in cadranul 2 sau 3 => punct asimptotic stabil 
#Pentru pi*z0 in cadranul 1 sau 4 => punct de echilibru instabil
#pt sin(pi*z0) in {1, -1} => Teorema nu decide f'(pi*z0) = 0
# Out:
# pi*z20
# cos(pi*z20)

# %%
#Prin grafic vom lamuri si ultima situatie
sf=plot_slope_field(f(s), (t, -5, 5), (s, -3, 3), headaxislength=3, headlength=4,color='red')
g1 = desolve_rk4(eq, x, [0, -pi/2], step=0.01, end_points = [-5, 5], output = 'plot')
g2 = desolve_rk4(eq, x, [0, -0.5], step=0.01, end_points = [-5, 5], output = 'plot')
g3 = desolve_rk4(eq, x, [0, 0], step=0.01, end_points = [-5, 5], output = 'plot')
g4 = desolve_rk4(eq, x, [0, 0.5], step=0.01, end_points = [-5, 5], output = 'plot')
g5 = desolve_rk4(eq, x, [0, 1], step=0.01, end_points = [-5, 5], output = 'plot')
g6 = desolve_rk4(eq, x, [0, pi/2], step=0.01, end_points = [-5, 5], output = 'plot')
g7 = desolve_rk4(eq, x, [0, 2], step=0.01, end_points = [-5, 5], output = 'plot')
g8 = desolve_rk4(eq, x, [0, 2.5], step=0.01, end_points = [-5, 5], output = 'plot')
g9 = desolve_rk4(eq, x, [0, pi], step=0.01, end_points = [-5, 5], output = 'plot')
g10 = desolve_rk4(eq, x, [0, pi + 1], step=0.01, end_points = [-5, 5], output = 'plot')
g = sf + g1 + g2 + g3 + g4 + g5 + g6 + g7 + g8 + g9 + g10
g.show(ymin = -3, ymax = 3)

#din grafic => 0 e instabil (atat ??)
# Out:
# Graphics object consisting of 11 graphics primitives

# %% [markdown]
# # Problema 2
#
# # a)

# %%
#Sistem liniar
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)

eq1 = diff(x) == 2*x + y
eq2 = diff(y) == x + 2*y
show(eq1, eq2)

s = var('s')
r = var('r')
f1 = function('f1')(s, r)
f2 = function('f2')(s, r)
f1(s, r) = 2*s + r
f2(s, r) = s + 2*r
show(f1)
show(f2)
sol = solve([f1(s, r) == 0, f2(s, r) == 0], s, r)
show(sol)

show("\nMatricea sistemului")
A = matrix([[2, 1], [1, -1]])
show(A)

A.eigenvalues()
show("\n Exista o valoare proprie strict pozitiva => (0, 0) Punct instabil")

cp(x) = A.charpoly()
cp

solve(cp==0, x)
# Out:
# diff(x(t), t) == 2*x(t) + y(t) diff(y(t), t) == x(t) + 2*y(t)
# (s, r) |--> r + 2*s
# (s, r) |--> 2*r + s
# [[s == 0, r == 0]]
# '\nMatricea sistemului'
# [ 2  1]
# [ 1 -1]
# '\n Exista o valoare proprie strict pozitiva => (0, 0) Punct instabil'
# [x == -1/2*sqrt(13) + 1/2, x == 1/2*sqrt(13) + 1/2]

# %%
p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,1,-1], ivar = t, end_points = [-1,1], step = 0.1)
XY = [ [j, k] for i, j, k in p]
XY

list_plot(XY, plotjoined = True, color = 'blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
n=sqrt(f1(s,r)^2+f2(s,r)^2)
g= plot_vector_field( [f1(s, r)/n, f2(s, r)/n], [s, -5, 5], [r, -5, 5], color = 'red', aspect_ratio = 1)

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,-1], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,1], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,2], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,-2], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,-1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,-2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')


g.show(xmin=-5, xmax= 5, ymin = -5, ymax =5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %% [markdown]
# # Problema 3
# # a)

# %%
reset()
x, y, t = var('x, y, t')
f1(x, y) = y
f2(x, y) = x*(1-x^2) + y
puncteE = solve([f1(x, y) == 0, f2(x, y) == 0], x, y)
show(puncteE)

show("\n Matricea Jacobiana a sistemului")
J = jacobian((f1(x, y), f2(x, y)), (x, y))
show(J)

show("\n Pe rand pentru punctele de echilibru ale sistemului")
show(J(x=-1, y=0))
show(J(x=-1, y=0).eigenvalues())
show(" [-1, 0] Instabil de tip focus\n")

show(J(x=1, y=0))
show(J(x=1, y=0).eigenvalues())
show(" [1, 0] Instabil de tip focus\n")

show(J(x=0, y=0))
show(J(x=0, y=0).eigenvalues())
show(" [0, 0] Instabil de tip sa\n")
# Out:
# [[x == -1, y == 0], [x == 1, y == 0], [x == 0, y == 0]]
# '\n Matricea Jacobiana a sistemului'
# [         0          1]
# [-3*x^2 + 1          1]
# '\n Pe rand pentru punctele de echilibru ale sistemului'
# [ 0  1]
# [-2  1]
# [-1/2*I*sqrt(7) + 1/2, 1/2*I*sqrt(7) + 1/2]
# ' [-1, 0] Instabil de tip focus\n'
# [ 0  1]
# [-2  1]
# [-1/2*I*sqrt(7) + 1/2, 1/2*I*sqrt(7) + 1/2]
# ' [1, 0] Instabil de tip focus\n'
# [0 1]
# [1 1]
# [-1/2*sqrt(5) + 1/2, 1/2*sqrt(5) + 1/2]
# ' [0, 0] Instabil de tip sa\n'

# %%
s, r = var('s, r')
n=sqrt(f1(s,r)^2+f2(s,r)^2)
g= plot_vector_field( [f1(s, r)/n, f2(s, r)/n], [s, -5, 5], [r, -5, 5], color = 'red', aspect_ratio = 1)

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,-1], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,1], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,2], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,-2], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,-1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,-2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

g.show(xmin=-5, xmax= 5, ymin = -5, ymax =5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %% [markdown]
# # b)

# %%
reset()
x, y, t = var('x, y, t')
f1(x, y) = -2*x + y + 2
f2(x, y) = x*y
puncteE = solve([f1(x,y) == 0, f2(x, y) == 0], [x, y])
show(puncteE)

show("\n Matricea Jacobiana a sistemului")
J = jacobian((f1(x, y), f2(x, y)), (x, y))
show(J)

show("\n Pe rand pentru punctele de echilibru ale sistemului")
show(J(x=1, y=0))
show(J(x=1, y=0).eigenvalues())
show(" [1, 0] Instabil de tip sa\n")

show(J(x=0, y=-2))
show(J(x=0, y=-2).eigenvalues())
show(" [0, -2] Instabil de tip focus\n")
# Out:
# [[x == 1, y == 0], [x == 0, y == -2]]
# '\n Matricea Jacobiana a sistemului'
# [-2  1]
# [ y  x]
# '\n Pe rand pentru punctele de echilibru ale sistemului'
# [-2  1]
# [ 0  1]
# [-2, 1]
# ' [1, 0] Instabil de tip sa\n'
# [-2  1]
# [-2  0]
# [-I - 1, I - 1]
# ' [0, -2] Instabil de tip focus\n'

# %%
s, r = var('s, r')
n=sqrt(f1(s,r)^2+f2(s,r)^2)
g= plot_vector_field( [f1(s, r)/n, f2(s, r)/n], [s, -5, 5], [r, -5, 5], color = 'red', aspect_ratio = 1)

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,-1], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,1], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,2], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,-2], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,-1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,-2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

g.show(xmin=-5, xmax= 5, ymin = -5, ymax =5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %% [markdown]
# # c)

# %%
reset()
x, y, t = var('x, y, t')
f1(x, y) = x^2 - y^2
f2(x, y) = x*y - 1

puncteE = solve([f1(x,y) == 0, f2(x, y) == 0], [x, y])
show(puncteE)
show("Extragem doar solutiile reale [-1, -1], [1, 1]\n")

show("\n Matricea Jacobiana a sistemului")
J = jacobian((f1(x, y), f2(x, y)), (x, y))
show(J)

show("\n Pe rand pentru punctele de echilibru ale sistemului")
show(J(x=-1, y=-1))
show(J(x=-1, y=-1).eigenvalues())
show(" [-1, -1] Local asimptotic stabil\n")

show(J(x=1, y=1))
show(J(x=1, y=1).eigenvalues())
show(" [1, 1] Instabil de tip focus\n")
# Out:
# [[x == -I, y == I], [x == I, y == -I], [x == -1, y == -1], [x == 1, y == 1]]
# 'Extragem doar solutiile reale [-1, -1], [1, 1]\n'
# '\n Matricea Jacobiana a sistemului'
# [ 2*x -2*y]
# [   y    x]
# '\n Pe rand pentru punctele de echilibru ale sistemului'
# [-2  2]
# [-1 -1]
# [-1/2*I*sqrt(7) - 3/2, 1/2*I*sqrt(7) - 3/2]
# ' [-1, -1] Local asimptotic stabil\n'
# [ 2 -2]
# [ 1  1]
# [-1/2*I*sqrt(7) + 3/2, 1/2*I*sqrt(7) + 3/2]
# ' [1, 1] Instabil de tip focus\n'

# %%
s, r = var('s, r')
n=sqrt(f1(s,r)^2+f2(s,r)^2)
g= plot_vector_field( [f1(s, r)/n, f2(s, r)/n], [s, -5, 5], [r, -5, 5], color = 'red', aspect_ratio = 1)

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,-1], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,1], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,2], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,-2], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,-1,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,-2,0], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

g.show(xmin=-5, xmax= 5, ymin = -5, ymax =5)
# Out:
# Graphics object consisting of 9 graphics primitives

# %% [markdown]
# # Problema 4
# # a)

# %%
reset()
t = var('t')
x = function('x')(t)
y = function('y')(t)
eq1 = diff(x, t) == 2*x - 1.2*x*y
eq2 = diff(y, t) == -y + 0.9*x*y
sol = desolve_system([eq1, eq2], [x,y])
show(sol)

solC = desolve_system([eq1, eq2], [x,y], [0, 0.5, 2])
show(solC)
# Out:
# [x(t) == ilt(-1/5*(6*laplace(x(t)*y(t), t, g5041) - 5*x(0))/(g5041 - 2), g5041, t),
#  y(t) == ilt(1/10*(9*laplace(x(t)*y(t), t, g5041) + 20)/(g5041 + 1), g5041, t)]
# [x(t) == ilt(-1/10*(12*laplace(x(t)*y(t), t, g5219) - 5)/(g5219 - 2), g5219, t),
#  y(t) == ilt(1/10*(9*laplace(x(t)*y(t), t, g5219) + 20)/(g5219 + 1), g5219, t)]

# %%
s, r = var('s, r')
f1(s, r) = 2*s - 1.2*s*r
f2(s, r) = -r + 0.9*s*r


n=sqrt(f1(s,r)^2+f2(s,r)^2)
g= plot_vector_field( [f1(s, r)/n, f2(s, r)/n], [s, -5, 5], [r, -5, 5], color = 'red', aspect_ratio = 1)

p = desolve_system_rk4([f1(s,r),f2(s,r)], [s,r], ics = [0,0,-1], ivar = t, end_points = [-5,5], step = 0.01)
XY = [ [j, k] for i, j, k in p]
g = g + list_plot(XY, plotjoined = True, color = 'blue')

g.show(xmin=-5, xmax= 5, ymin = -5, ymax =5)
# Out:
# Graphics object consisting of 2 graphics primitives
