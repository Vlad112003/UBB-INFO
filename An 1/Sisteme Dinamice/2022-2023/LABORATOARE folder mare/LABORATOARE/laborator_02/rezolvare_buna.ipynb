# %% [raw]
# #laborator 2
# Exercitiul 1

# %% [raw]
# a)

# %%
x = var('x')
y = function('y')(x)
eqd1 = diff(y, x) == 2*x*(1+y^2)
show(eqd1)
# Out:
# diff(y(x), x) == 2*(y(x)^2 + 1)*x

# %%
sol_implicit1 = desolve(eqd1, y)
solve(sol_implicit1, y)
# Out:
# [y(x) == tan(x^2 + 2*_C)]

# %% [raw]
# b)

# %%
x = var('x')
y = function('y')(x)
eqd2 = (x^2 - 1) * diff(y, x) + 2*x*y^2 == 0
show(eqd2)
# Out:
# 2*x*y(x)^2 + (x^2 - 1)*diff(y(x), x) == 0

# %%
sol_implicit2 = desolve(eqd2, y)
solve(sol_implicit2, y)
# Out:
# [y(x) == (1/(2*_C + log(x + 1) + log(x - 1)))]

# %% [raw]
# c)

# %%
x = var('x')
y = function('y')(x)
eqd = 2 * x^2*diff(y, x) == x^2 + y^2
show(eqd)
# Out:
# 2*x^2*diff(y(x), x) == x^2 + y(x)^2

# %%
sol_implicit = desolve(eqd, y)
solve(sol_implicit, y)
# Out:
# [y(x) == (x*log(-1/sqrt(_C*x)) + x)/log(-1/sqrt(_C*x)), y(x) == (x*log(_C*x) - 2*x)/log(_C*x)]

# %% [raw]
# d)

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) == -(x+y)/(y)
show(eqd)
# Out:
# diff(y(x), x) == -(x + y(x))/y(x)

# %%
sol_implicit = desolve(eqd, y)
show(sol_implicit)
# Out:
# _C*x == e^(-1/6*sqrt(3)*(sqrt(3)*log((x^2 + x*y(x) + y(x)^2)/x^2) - 2*arctan(1/3*sqrt(3)*(x + 2*y(x))/x)))

# %% [raw]
# e)

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x, 2) + y == sin(x) + cos(x)
show(eqd)
# Out:
# y(x) + diff(y(x), x, x) == cos(x) + sin(x)

# %%
sol_implicit = desolve(eqd, y)
sol_implicit
# Out:
# _K2*cos(x) - 1/2*(x - 1)*cos(x) + _K1*sin(x) + 1/2*x*sin(x)

# %% [raw]
# f)

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x, 2) - y == exp(2*x)
show(eqd)
# Out:
# -y(x) + diff(y(x), x, x) == e^(2*x)

# %%
sol_implicit = desolve(eqd, y)
sol_implicit
# Out:
# _K2*e^(-x) + _K1*e^x + 1/3*e^(2*x)

# %% [raw]
# g)

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x, 2) - diff(y, x) == 1/(1 + exp(x))
show(eqd)
# Out:
# -diff(y(x), x) + diff(y(x), x, x) == (1/(e^x + 1))

# %%
sol_implicit = desolve(eqd, y)
sol_implicit
# Out:
# _K1*e^x + e^x*log((e^x + 1)*e^(-x)) + _K2 - x + log(e^x + 1)

# %% [raw]
# Exercitiul 2

# %% [raw]
# a)

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) == 1 + y^2
show(eqd)
# Out:
# diff(y(x), x) == y(x)^2 + 1

# %%
sol_implicit = desolve(eqd, y, ics = [0,1])
sol_explicit = solve(sol_implicit, y)
show(sol_explicit)
# Out:
# [y(x) == tan(1/4*pi + x)]

# %%
plot(sol_explicit[0].rhs(), xmin = -10, xmax = 10,  ymin = -10, ymax = 10, detect_poles = true)
# Out:
# Graphics object consisting of 8 graphics primitives

# %% [raw]
# b)

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) == 1/(1 - x^2)*y + 1 + x
show(eqd)
# Out:
# diff(y(x), x) == x - y(x)/(x^2 - 1) + 1

# %%
sol_implicit = desolve(eqd, y, ics = [2,0])
show(sol_implicit)
# Out:
# 1/2*(sqrt(x^2 - 1)*sqrt(x + 1)*x - sqrt(x + 1)*(2*sqrt(3) - log(2*sqrt(3) + 4)) - sqrt(x + 1)*log(2*x + 2*sqrt(x^2 - 1)))/sqrt(x - 1)

# %%
plot(sol_implicit, x, 1.1, 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# c)

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x) - 2 * y == -(x^2)
show(eqd)
# Out:
# -2*y(x) + diff(y(x), x) == -x^2

# %%
sol_implicit = desolve(eqd, y, ics = [0,1./4])
show(sol_implicit)
# Out:
# 1/2*x^2 + 1/2*x + 1/4

# %%
plot(sol_implicit, x, -10, 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# d)

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x, 2) - 5 * diff(y, x) + 4 *y == 0
show(eqd)
# Out:
# 4*y(x) - 5*diff(y(x), x) + diff(y(x), x, x) == 0

# %%
sol_implicit = desolve(eqd, y, ics = [0, 5, 8])
show(sol_implicit)
# Out:
# e^(4*x) + 4*e^x

# %%
plot(sol_implicit, x, -10, 10, ymax = 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# e)

# %%
x = var('x')
y = function('y')(x)
eqd = diff(y, x, 2) - 4 * diff(y, x) + 5 * y == 2 * x^2 * exp(x)
show(eqd)
# Out:
# 5*y(x) - 4*diff(y(x), x) + diff(y(x), x, x) == 2*x^2*e^x

# %%
sol_implicit = desolve(eqd, y, ics = [0, 2, 3])
show(sol_implicit)
# Out:
# (cos(x) - 2*sin(x))*e^(2*x) + (x^2 + 2*x + 1)*e^x

# %%
plot(sol_implicit, x, xmin = -10, xmax = 10, ymin = -10, ymax = 10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# f)

# %%
x = var('x')
y = function ('y')(x)
eqd = diff(y, x, 2) + 4 * y == 4 * (sin(2*x) + cos(2*x))
show(eqd)
# Out:
# 4*y(x) + diff(y(x), x, x) == 4*cos(2*x) + 4*sin(2*x)

# %%
sol_implicit = desolve(eqd, y, ics = [pi, 2*pi, 2*pi])
show(sol_implicit)
# Out:
# 1/2*(6*pi - 1)*cos(2*x) - 1/2*(2*x - 1)*cos(2*x) + x*sin(2*x) + 1/2*sin(2*x)

# %%
plot(sol_implicit, x, xmin = -10, xmax = 10, ymin = -20, ymax = 20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# Exercitiul 3

# %% [raw]
# a)

# %%
x, k = var('x, k')
y = function ('y')(x)
eqd = diff(y, x) + k/x*y == x^3
show(eqd)
# Out:
# k*y(x)/x + diff(y(x), x) == x^3

# %%
sol_implicit = desolve(eqd, [y, x])
show(sol_implicit)
# Out:
# (x^4*x^k/(k + 4) + _C)/x^k

# %% [raw]
# b)

# %%
x, k = var('x, k')
y = function ('y')(x)
eqd = diff(y, x) + k/x*y == x^3
sol_implicit(x, k, _C) = desolve(eqd, [y, x])
show(sol_implicit(x, k, _C))
# Out:
# (x^4*x^k/(k + 4) + _C)/x^k

# %%
list = [sol_implicit(x, 1, i/10) for i in [10..15]]
plot(list, x, -0.5, 0.5, ymin = -20, ymax = 20)
# Out:
# Graphics object consisting of 6 graphics primitives

# %% [raw]
# c)

# %%
x, k = var('x, k')
y = function ('y')(x)
eqd = diff(y, x) + k/x*y == x^3
sol_implicit(x, k, _C) = desolve(eqd, [y, x], ics = [1, 0])
show(sol_implicit(x, k, _C))

list = [sol_implicit(x, 1, i/10) for i in [10..15]]
plot(list, x, -5, 5, ymin = -20, ymax = 20, detect_poles = true)
# Out:
# (x^4*x^k - 1)/((k + 4)*x^k)
# Graphics object consisting of 12 graphics primitives

# %% [raw]
# d)

# %%
x, k = var('x, k')
y = function ('y')(x)
eqd = diff(y, x) + k/x*y == x^3
sol_implicit(x, k) = desolve(eqd, [y, x], ics = [1, 0])
show(sol_implicit(x, k))

solutii = [plot(sol_implicit(x, k), x, -5, 5, ymin = -10, ymax = 10, detect_poles = true) for k in [0..50]]
animate(solutii)
# Out:
# (x^4*x^k - 1)/((k + 4)*x^k)
# Animation with 51 frames

# %% [raw]
# Exercitiul 4

# %%
x, a, b = var('x, a, b')
y = function('y')(x)
eqd = diff(y, x) == y + a*x + b
show(eqd)
# Out:
# diff(y(x), x) == a*x + b + y(x)

# %%
sol_implicit(x) = desolve(eqd, [y, x], ics = [0, 1])
show(sol_implicit(x))
# Out:
# -a*x + (a + b + 1)*e^x - a - b

# %%
eqdA = sol_implicit(1) == -5 + 4 * e
show(eqdA)
# Out:
# (a + b + 1)*e - 2*a - b == 4*e - 5

# %%
eqdB = sol_implicit(2) == -7 + 4*e^2
show(eqdB)
# Out:
# (a + b + 1)*e^2 - 3*a - b == 4*e^2 - 7

# %%
sist = [eqdA, eqdB]
show(sist)
# Out:
# [(a + b + 1)*e - 2*a - b == 4*e - 5, (a + b + 1)*e^2 - 3*a - b == 4*e^2 - 7]

# %%
solve(sist, a, b)
# Out:
# [[a == 2, b == 1]]

# %%
show(sol_implicit(x).substitute(a == 2, b == 1))
plot(sol_implicit(x).substitute(a == 2, b == 1))
# Out:
# -2*x + 4*e^x - 3
# Graphics object consisting of 1 graphics primitive

# %% [raw]
# Exercitiul 5

# %%
x, a = var('x, a')
y = function('y')(x)
eqd = diff(y, x, 2) - diff(y, x) - 2 * y == 0
show(eqd)
# Out:
# -2*y(x) - diff(y(x), x) + diff(y(x), x, x) == 0

# %%
sol_implicit(x, a) = desolve(eqd, [y, x], ics = [0, a, 2])
show(sol_implicit(x, a))
# Out:
# 1/3*(a + 2)*e^(2*x) + 2/3*(a - 1)*e^(-x)

# %%
assume(a>-2)
limit(sol_implicit(x, a), x = infinity )
# Out:
# +Infinity

# %%
forget()
assume(a<-2)
limit(sol_implicit(x, a), x = infinity )
# Out:
# -Infinity

# %%
forget()
limit(sol_implicit(x, -2), x = infinity )
# Out:
# 0
